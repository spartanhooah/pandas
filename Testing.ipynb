# %%
import pandas

# %%
df = pandas.read_csv("data/supermarkets.csv")

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.75292099814533, -122.43170295955227, 0.0))

# %%
nom.geocode("3995 23rd St San Francisco, CA 94114")
# Out:
# Location(3995 23rd St, San Francisco, California, 94114, (37.75292099814533, -122.43170295955227, 0.0))

# %%
location = nom.geocode("3995 23rd St, San Francisco, CA 94114")
location.latitude
# Out:
# 37.75292099814533

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"] = df["Address"] + ", " + df["City"] + ", " + df["State"] + ", " + df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"] = df["Address"].apply(nom.geocode)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# ...

# %%
df["Coordinates"] = df["Address"].apply(nom.geocode).latitude
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 df["Coordinates"] = df["Address"].apply(nom.geocode).latitude
#       2 df
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:5907, in NDFrame.__getattr__(self, name)
#    <a href='file:///home/spartanhooah/.local/lib/python3.10/site-packages/pandas/core/generic.py?line=5899'>5900</a> if (
#    <a href='file:///home/spartanhooah/.local/lib/python3.10/site-packages/pandas/core/generic.py?line=5900'>5901</a>     name not in self._internal_names_set
#    <a href='file:///home/spartanhooah/.local/lib/python3.10/site-packages/pandas/core/generic.py?line=5901'>5902</a>     and name not in self._metadata
#    <a href='file:///home/spartanhooah/.local/lib/python3.10/site-packages/pandas/core/generic.py?line=5902'>5903</a>     and name not in self._accessors
# ...

# %%
df["Coordinates"] = df["Address"].apply(nom.geocode).apply(latitude)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 df["Coordinates"] = df["Address"].apply(nom.geocode).apply(latitude)
#       2 df
#
# NameError: name 'latitude' is not defined

# %%
df["Coordinates"] = df["Address"].apply(nom.geocode).apply(lambda x: x.latitude)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  Coordinates
# 0          CA 94114     USA      Madeira          8    37.756632
# 1          CA 94119     USA  Bready Shop         15    37.757829
# 2  California 94114     USA  Super River         25    37.755845
# 3          CA 94114     USA   Ben's Shop         10    37.752921
# 4        California     USA      Sanchez         12    37.752132
# 5          CA 94114     USA   Richvalley         20    37.753582

# %%
df["Coordinates"] = df["Address"].apply(nom.geocode).apply(lambda x: (x.latitude, x.longitude))
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                  Coordinates
# 0  (37.756632001957215, -122.42941101194798)
# ...
